# %%
import pandas as pd
import numpy as np

# %%
people={
    'first':["Ram","Raj","Shyam","Tom",np.nan,"Missing","ramu"],
    'last':['Patil','Pawar','Jadhav','koth','Patil','Bhosale',np.nan],
    'contact':[101,102,103,104,105,106,107],
    'age':[20,21,23,24,25,26,28],
    'extra':[np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#      first     last  contact  age  extra
# 0      Ram    Patil      101   20    NaN
# 1      Raj    Pawar      102   21    NaN
# 2    Shyam   Jadhav      103   23    NaN
# 3      Tom     koth      104   24    NaN
# 4      NaN    Patil      105   25    NaN
# 5  Missing  Bhosale      106   26    NaN
# 6     ramu      NaN      107   28    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   first    6 non-null      object
#  1   last     6 non-null      object
#  2   contact  7 non-null      int64
#  3   age      7 non-null      int64
#  4   extra    0 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 412.0+ bytes

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   first    5 non-null      object
#  1   last     5 non-null      object
#  2   contact  5 non-null      int64
#  3   age      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 200.0+ bytes

# %%
df.dropna(axis='columns',how='all',inplace=True)

# %%
df
# Out:
#      first     last  contact  age
# 0      Ram    Patil      101   20
# 1      Raj    Pawar      102   21
# 2    Shyam   Jadhav      103   23
# 3      Tom     koth      104   24
# 4      NaN    Patil      105   25
# 5  Missing  Bhosale      106   26
# 6     ramu      NaN      107   28

# %%
df
# Out:
#      first     last  contact  age
# 0      Ram    Patil      101   20
# 1      Raj    Pawar      102   21
# 2    Shyam   Jadhav      103   23
# 3      Tom     koth      104   24
# 5  Missing  Bhosale      106   26

# %%
peoples={
    'first':["Ram","Raj","Shyam","Tom",np.nan,"Missing","ramu"],
    'last':['Patil','Pawar','Jadhav','koth','Patil','Bhosale',np.nan],
    'contact':[101,102,103,104,105,106,107],
    'age':[20,21,23,24,25,26,28],
}

# %%
df1=pd.DataFrame(peoples)

# %%
df1
# Out:
#      first     last  contact  age
# 0      Ram    Patil      101   20
# 1      Raj    Pawar      102   21
# 2    Shyam   Jadhav      103   23
# 3      Tom     koth      104   24
# 4      NaN    Patil      105   25
# 5  Missing  Bhosale      106   26
# 6     ramu      NaN      107   28

# %%
df.dropna(axis='index',how='any',subset=['first'],inplace=True)

# %%
df
# Out:
#      first     last  contact  age
# 0      Ram    Patil      101   20
# 1      Raj    Pawar      102   21
# 2    Shyam   Jadhav      103   23
# 3      Tom     koth      104   24
# 5  Missing  Bhosale      106   26

# %%
df.drop(index=[5],inplace=True)

# %%
df
# Out:
#    first    last  contact  age
# 0    Ram   Patil      101   20
# 1    Raj   Pawar      102   21
# 2  Shyam  Jadhav      103   23
# 3    Tom    koth      104   24

# %%
df.isna().value_counts()
# Out:
# first  last   contact  age
# False  False  False    False    4
# Name: count, dtype: int64

# %%
people={
    'first':["Ram","Raj","Shyam","Tom",np.nan,"Missing","ramu"],
    'last':['Patil','Pawar','Jadhav','koth','Patil','Bhosale',np.nan],
    'contact':[101,102,103,104,105,106,107],
    'age':[20,21,23,24,25,26,28],
    'extra':[np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
}

# %%
df2=pd.DataFrame(people)

# %%
df2
# Out:
#      first     last  contact  age  extra
# 0      Ram    Patil      101   20    NaN
# 1      Raj    Pawar      102   21    NaN
# 2    Shyam   Jadhav      103   23    NaN
# 3      Tom     koth      104   24    NaN
# 4      NaN    Patil      105   25    NaN
# 5  Missing  Bhosale      106   26    NaN
# 6     ramu      NaN      107   28    NaN

# %%
df2.isna()
# Out:
#    first   last  contact    age  extra
# 0  False  False    False  False   True
# 1  False  False    False  False   True
# 2  False  False    False  False   True
# 3  False  False    False  False   True
# 4   True  False    False  False   True
# 5  False  False    False  False   True
# 6  False   True    False  False   True

# %%
df2.fillna('Missing')
# Out:
#      first     last  contact  age    extra
# 0      Ram    Patil      101   20  Missing
# 1      Raj    Pawar      102   21  Missing
# 2    Shyam   Jadhav      103   23  Missing
# 3      Tom     koth      104   24  Missing
# 4  Missing    Patil      105   25  Missing
# 5  Missing  Bhosale      106   26  Missing
# 6     ramu  Missing      107   28  Missing

# %%
df2.replace('Missing',np.nan,inplace=True)

# %%
df.dtypes
# Out:
# first      object
# last       object
# contact     int64
# age         int64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(22.0)

# %%
df['age']=df['age'].astype('str')

# %%
df.dtypes
# Out:
# first      object
# last       object
# contact     int64
# age        object
# dtype: object

# %%
df['age']=df['age'].astype('int')

# %%
df.dtypes
# Out:
# first      object
# last       object
# contact     int64
# age         int64
# dtype: object

# %%
df=pd.read_csv("DailyDelhiClimateTrain.csv")

# %%
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.dtypes
# Out:
# date             object
# meantemp        float64
# humidity        float64
# wind_speed      float64
# meanpressure    float64
# dtype: object

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date            datetime64[ns]
# meantemp               float64
# humidity               float64
# wind_speed             float64
# meanpressure           float64
# dtype: object

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(
#     arg: 'DatetimeScalarOrArrayConvertible | DictConvertible',
#     errors: 'DateTimeErrorChoices' = 'raise',
#     dayfirst: 'bool' = False,
#     yearfirst: 'bool' = False,
#     utc: 'bool' = False,
#     format: 'str | None' = None,
#     exact: 'bool | lib.NoDefault' = <no_default>,
#     unit: 'str | None' = None,
#     infer_datetime_format: 'lib.NoDefault | bool' = <no_default>,
#     origin: 'str' = 'unix',
#     cache: 'bool' = True
# ) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType | None'
#     Convert argument to datetime.
#
#     This function converts a scalar, array-like, :class:`Series` or
#     :class:`DataFrame`/dict-like to a pandas datetime object.
#
#     Parameters
#     ----------
#     arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#         The object to convert to a datetime. If a :class:`DataFrame` is provided, the
# ...

# %%
df
# Out:
#            date   meantemp    humidity  wind_speed  meanpressure
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...         ...        ...         ...         ...           ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.loc[0,'date'].day_name()
# Out:
# 'Tuesday'
