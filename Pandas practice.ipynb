# %%
import pandas as pd

# %%
data={
    "student":["Amit","Ram","Shyam","Bablu","Jacob"],
    "marks":[100,90,80,70,60],
    "rank":[1,2,3,4,5]
}

# %%
df=pd.DataFrame(data=data,index=[1,2,3,4,5])

# %%
df
# Out:
#   student  marks  rank
# 1    Amit    100     1
# 2     Ram     90     2
# 3   Shyam     80     3
# 4   Bablu     70     4
# 5   Jacob     60     5

# %%
df.iloc[[1,2]]
# Out:
#   student  marks  rank
# 2     Ram     90     2
# 3   Shyam     80     3

# %%
df.iloc[[1,2],[0,1]]
# Out:
#   student  marks
# 2     Ram     90
# 3   Shyam     80

# %%
for col in df:
    print(col)
# Out:
# student
# marks
# rank

# %%
df.dtypes
# Out:
# student    object
# marks       int64
# rank        int64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 15

# %%
df.shape
# Out:
# (5, 3)

# %%
df.index
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df.T
# Out:
#             1    2      3      4      5
# student  Amit  Ram  Shyam  Bablu  Jacob
# marks     100   90     80     70     60
# rank        1    2      3      4      5

# %%
df.head(2)
# Out:
#   student  marks  rank
# 1    Amit    100     1
# 2     Ram     90     2

# %%
df.tail(3)
# Out:
#   student  marks  rank
# 3   Shyam     80     3
# 4   Bablu     70     4
# 5   Jacob     60     5

# %%
data1={
    "student":["Amit","Ram","Shyam","Bablu","Jacob"],
    "marks":[100,90,80,70,60],
}

# %%
data2={
    "rank":[1,2,3,4,5],
    "address":["sangli","pune","satara",'kolhapur',"ashta"]
}

# %%
df1=pd.DataFrame(data1)

# %%
df2=pd.DataFrame(data2)

# %%
resdf=df1.join(df2)

# %%
resdf
# Out:
#   student  marks  rank   address
# 0    Amit    100     1    sangli
# 1     Ram     90     2      pune
# 2   Shyam     80     3    satara
# 3   Bablu     70     4  kolhapur
# 4   Jacob     60     5     ashta

# %%
data1={
    "student":["Amit","Ram","Shyam","Bablu","Jacob"],
    "marks":[100,90,80,70,60],
    "rank":[1,2,3,4,5]
}

# %%
data2={
    "student":["Amit","Ram","Shyam","Bablu","Jacob"],
    "marks":[100,90,80,70,60],
    "rank":[1,2,3,4,5]
}

# %%
df1=pd.DataFrame(data1)

# %%
df2=pd.DataFrame(data2)

# %%
resdf=pd.concat((df1,df2),ignore_index=True)

# %%
resdf
# Out:
#   student  marks  rank
# 0    Amit    100     1
# 1     Ram     90     2
# 2   Shyam     80     3
# 3   Bablu     70     4
# 4   Jacob     60     5
# 5    Amit    100     1
# 6     Ram     90     2
# 7   Shyam     80     3
# 8   Bablu     70     4
# 9   Jacob     60     5

# %%
data=[10,20,30,40,50,60,70,80,80,100]

# %%
s=pd.Series(data)

# %%
s
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     70
# 7     80
# 8     80
# 9    100
# dtype: int64

# %%
s[5]
# Out:
# np.int64(60)

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 10

# %%
s.shape
# Out:
# (10,)

# %%
s.name

# %%
s.hasnans
# Out:
# False

# %%
s.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
s.head(4)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s.tail()
# Out:
# 5     60
# 6     70
# 7     80
# 8     80
# 9    100
# dtype: int64

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10 entries, 0 to 9
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 10 non-null     int64
# dtypes: int64(1)
# memory usage: 212.0 bytes

# %%
data1=[10,20,30,40,50]

# %%
s1=pd.Series(data1)

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data2=[60,70,80,90,100]

# %%
s2=pd.Series(data2)

# %%
s2
# Out:
# 0     60
# 1     70
# 2     80
# 3     90
# 4    100
# dtype: int64

# %%
def bigger(x,y):
    if(x>y):
        return x
    else:
        return y
ress=s1.combine(s2,bigger)

# %%
ress
# Out:
# 0     60
# 1     70
# 2     80
# 3     90
# 4    100
# dtype: int64

# %%
s=pd.Series(data=['A','B','C','D','E','F'],dtype="category")

# %%
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# dtype: category
# Categories (6, object): ['A', 'B', 'C', 'D', 'E', 'F']

# %%
df=pd.DataFrame(data=['A','B','C','D','E','F'],dtype='category')

# %%
df
# Out:
#    0
# 0  A
# 1  B
# 2  C
# 3  D
# 4  E
# 5  F

# %%
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# dtype: category
# Categories (6, object): ['A', 'B', 'C', 'D', 'E', 'F']

# %%
s=s.cat.add_categories('G')

# %%
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
s=s.cat.remove_categories('G')

# %%
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# dtype: category
# Categories (6, object): ['A', 'B', 'C', 'D', 'E', 'F']

# %%
df=pd.read_excel("Student.xlsx",index_col='Name')

# %%
df
# Out:
#        Marks  Rank
# Name
# Ram      100     1
# Raj       90     2
# Shyam     80     3
# Pintu     70     4

# %%
df.loc["Ram",'Rank']
# Out:
# np.int64(1)

# %%
df["Marks"]
# Out:
# Name
# Ram      100
# Raj       90
# Shyam     80
# Pintu     70
# Name: Marks, dtype: int64

# %%
df.reset_index()
# Out:
#     Name  Marks  Rank
# 0    Ram    100     1
# 1    Raj     90     2
# 2  Shyam     80     3
# 3  Pintu     70     4

# %%
df.iloc[0,1]
# Out:
# np.int64(1)

# %%
df.insert(2,"roll",[101,102,103,104])

# %%
df
# Out:
#        Marks  Rank  roll
# Name
# Ram      100     1   101
# Raj       90     2   102
# Shyam     80     3   103
# Pintu     70     4   104

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Name  Marks  Rank  roll
# 0    Ram    100     1   101
# 1    Raj     90     2   102
# 2  Shyam     80     3   103
# 3  Pintu     70     4   104

# %%
df=df.assign(address=["sangli",'ashta','vadgoa','pune'])

# %%
df
# Out:
#     Name  Marks  Rank  roll address
# 0    Ram    100     1   101  sangli
# 1    Raj     90     2   102   ashta
# 2  Shyam     80     3   103  vadgoa
# 3  Pintu     70     4   104    pune

# %%
df.drop('roll',axis='columns',inplace=True)

# %%
df
# Out:
#     Name  Marks  Rank address
# 0    Ram    100     1  sangli
# 1    Raj     90     2   ashta
# 2  Shyam     80     3  vadgoa
# 3  Pintu     70     4    pune

# %%
df.drop(3,axis='index',inplace=True)

# %%
df
# Out:
#     Name  Marks  Rank address
# 0    Ram    100     1  sangli
# 1    Raj     90     2   ashta
# 2  Shyam     80     3  vadgoa

# %%
df.to_csv("clean.csv",index=False)

# %%
df=pd.read_csv("clean.csv")

# %%
df
# Out:
#     Name  Marks  Rank address
# 0    Ram    100     1  sangli
# 1    Raj     90     2   ashta
# 2  Shyam     80     3  vadgoa

# %%
for row in df.iterrows():
    print(row)
    print()
# Out:
# (0, Name          Ram
# Marks         100
# Rank            1
# address    sangli
# Name: 0, dtype: object)
#
# (1, Name         Raj
# Marks         90
# Rank           2
# address    ashta
# Name: 1, dtype: object)
#
# (2, Name        Shyam
# Marks          80
# Rank            3
# address    vadgoa
# Name: 2, dtype: object)

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Name='Ram', Marks=100, Rank=1, address='sangli')
# Pandas(Index=1, Name='Raj', Marks=90, Rank=2, address='ashta')
# Pandas(Index=2, Name='Shyam', Marks=80, Rank=3, address='vadgoa')

# %%
data={
    'student':["Amit","John","Jacob","David","Sleve"],
    'rank':[1,4,3,5,2],
    'marks':[95,70,80,60,90]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 2   Jacob     3     80
# 3   David     5     60
# 4   Sleve     2     90

# %%
res=df.sort_values(by='rank')

# %%
res
# Out:
#   student  rank  marks
# 0    Amit     1     95
# 4   Sleve     2     90
# 2   Jacob     3     80
# 1    John     4     70
# 3   David     5     60

# %%
res=df.sort_values(by='rank',ascending=False)

# %%
res
# Out:
#   student  rank  marks
# 3   David     5     60
# 1    John     4     70
# 2   Jacob     3     80
# 4   Sleve     2     90
# 0    Amit     1     95

# %%
data={
    'student':["Amit","John","Jacob","David","Sleve","Amit","Jacob"],
    'rank':[1,4,3,5,2,1,3],
    'marks':[95,70,80,60,90,95,80]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 2   Jacob     3     80
# 3   David     5     60
# 4   Sleve     2     90
# 5    Amit     1     95
# 6   Jacob     3     80

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
res=df.drop_duplicates()

# %%
res
# Out:
#   student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 2   Jacob     3     80
# 3   David     5     60
# 4   Sleve     2     90

# %%
import numpy as np

# %%
data={
    'student':["Amit","John","Jacob",np.nan,"Sleve","Amit",np.nan],
    'rank':[1,4,3,np.nan,2,1,3],
    'marks':[95,70,80,60,np.nan,95,80]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3     NaN   NaN   60.0
# 4   Sleve   2.0    NaN
# 5    Amit   1.0   95.0
# 6     NaN   3.0   80.0

# %%
resdf=df.isnull()

# %%
resdf
# Out:
#    student   rank  marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3     True   True  False
# 4    False  False   True
# 5    False  False  False
# 6     True  False  False

# %%
resdf.count()
# Out:
# student    7
# rank       7
# marks      7
# dtype: int64

# %%
resdf=df.notnull()

# %%
resdf
# Out:
#    student   rank  marks
# 0     True   True   True
# 1     True   True   True
# 2     True   True   True
# 3    False  False   True
# 4     True   True  False
# 5     True   True   True
# 6    False   True   True

# %%
df
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3     NaN   NaN   60.0
# 4   Sleve   2.0    NaN
# 5    Amit   1.0   95.0
# 6     NaN   3.0   80.0

# %%
resdf=df.dropna(ignore_index=True)

# %%
resdf
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3    Amit   1.0   95.0

# %%
df
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3     NaN   NaN   60.0
# 4   Sleve   2.0    NaN
# 5    Amit   1.0   95.0
# 6     NaN   3.0   80.0

# %%
df['student']=df['student'].fillna("Tom")

# %%
df
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3     Tom   NaN   60.0
# 4   Sleve   2.0    NaN
# 5    Amit   1.0   95.0
# 6     Tom   3.0   80.0

# %%
df['rank']=df['rank'].fillna(df['rank'].mean())

# %%
df
# Out:
#   student      rank  marks
# 0    Amit  1.000000   95.0
# 1    John  4.000000   70.0
# 2   Jacob  3.000000   80.0
# 3     Tom  2.333333   60.0
# 4   Sleve  2.000000    NaN
# 5    Amit  1.000000   95.0
# 6     Tom  3.000000   80.0

# %%
df['marks']=df['marks'].fillna(df['marks'].mean())

# %%
df
# Out:
#   student      rank  marks
# 0    Amit  1.000000   95.0
# 1    John  4.000000   70.0
# 2   Jacob  3.000000   80.0
# 3     Tom  2.333333   60.0
# 4   Sleve  2.000000   80.0
# 5    Amit  1.000000   95.0
# 6     Tom  3.000000   80.0

# %%
df
# Out:
#   student      rank  marks
# 0    Amit  1.000000   95.0
# 1    John  4.000000   70.0
# 2   Jacob  3.000000   80.0
# 3     Tom  2.333333   60.0
# 4   Sleve  2.000000   80.0
# 5    Amit  1.000000   95.0
# 6     Tom  3.000000   80.0

# %%
df['student']=df['student'].str.lower()

# %%
df
# Out:
#   student      rank  marks
# 0    amit  1.000000   95.0
# 1    john  4.000000   70.0
# 2   jacob  3.000000   80.0
# 3     tom  2.333333   60.0
# 4   sleve  2.000000   80.0
# 5    amit  1.000000   95.0
# 6     tom  3.000000   80.0

# %%
df['student']=df['student'].str.upper()

# %%
df
# Out:
#   student      rank  marks
# 0    AMIT  1.000000   95.0
# 1    JOHN  4.000000   70.0
# 2   JACOB  3.000000   80.0
# 3     TOM  2.333333   60.0
# 4   SLEVE  2.000000   80.0
# 5    AMIT  1.000000   95.0
# 6     TOM  3.000000   80.0

# %%
df['student']=df['student'].str.title()

# %%
df
# Out:
#   student      rank  marks
# 0    Amit  1.000000   95.0
# 1    John  4.000000   70.0
# 2   Jacob  3.000000   80.0
# 3     Tom  2.333333   60.0
# 4   Sleve  2.000000   80.0
# 5    Amit  1.000000   95.0
# 6     Tom  3.000000   80.0

# %%
df['student']=df['student'].str.len()

# %%
df
# Out:
#    student      rank  marks
# 0        4  1.000000   95.0
# 1        4  4.000000   70.0
# 2        5  3.000000   80.0
# 3        3  2.333333   60.0
# 4        5  2.000000   80.0
# 5        4  1.000000   95.0
# 6        3  3.000000   80.0

# %%
df['student'].count()
# Out:
# np.int64(7)

# %%
resdf.str.contains('Amit')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\MyTemp\ipykernel_1948\960248497.py in ?()
# ----> 1 resdf.str.contains('Amit')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
resdf
# Out:
#   student  rank  marks
# 0    Amit   1.0   95.0
# 1    John   4.0   70.0
# 2   Jacob   3.0   80.0
# 3    Amit   1.0   95.0

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-03-28 13:01:53.818121')

# %%
ts=pd.Timestamp(year=2024 , month=11,day=10)

# %%
ts
# Out:
# Timestamp('2024-11-10 00:00:00')

# %%
ts.dayofweek
# Out:
# 6

# %%
ts.dayofyear
# Out:
# 315

# %%
ts.daysinmonth
# Out:
# 30

# %%
ts.is_leap_year
# Out:
# True

# %%
ts.is_month_end
# Out:
# False

# %%
ts.is_month_start
# Out:
# False

# %%
ts.is_year_end
# Out:
# False

# %%
ts.is_year_start
# Out:
# False

# %%
data=["\n\traju\n","\n\tram\n","\n\tShyam\t\n","\n\tRutwik\n"]

# %%
s=pd.Series(data)

# %%
s
# Out:
# 0       \n\traju\n
# 1        \n\tram\n
# 2    \n\tShyam\t\n
# 3     \n\tRutwik\n
# dtype: object

# %%
s.str.strip()
# Out:
# 0      raju
# 1       ram
# 2     Shyam
# 3    Rutwik
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0       raju\n
# 1        ram\n
# 2    Shyam\t\n
# 3     Rutwik\n
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0      \n\traju
# 1       \n\tram
# 2     \n\tShyam
# 3    \n\tRutwik
# dtype: object
