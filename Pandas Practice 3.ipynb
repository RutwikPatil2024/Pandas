# %%
import pandas as pd

# %%
people={
    'first':['harry','ram','shyam','pandav'],
    'last':['patil','pawar','bhosale','jadhav'],
    'email':['uvw@gmail.com','xyz@gmail.com','pqr@gmail.com','abcgmail.com'],
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last          email
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.set_index('first',inplace=True)

# %%
df
# Out:
#            last          email
# first
# harry     patil  uvw@gmail.com
# ram       pawar  xyz@gmail.com
# shyam   bhosale  pqr@gmail.com
# pandav   jadhav   abcgmail.com

# %%
df[['last','email']]
# Out:
#            last          email
# first
# harry     patil  uvw@gmail.com
# ram       pawar  xyz@gmail.com
# shyam   bhosale  pqr@gmail.com
# pandav   jadhav   abcgmail.com

# %%
df.index
# Out:
# Index(['harry', 'ram', 'shyam', 'pandav'], dtype='object', name='first')

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     first     last          email
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df.set_index('first',inplace=True)

# %%
df
# Out:
#            last          email
# first
# harry     patil  uvw@gmail.com
# ram       pawar  xyz@gmail.com
# shyam   bhosale  pqr@gmail.com
# pandav   jadhav   abcgmail.com

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#            last          email
# first
# harry     patil  uvw@gmail.com
# pandav   jadhav   abcgmail.com
# ram       pawar  xyz@gmail.com
# shyam   bhosale  pqr@gmail.com

# %%
df.sort_index(ascending=False)
# Out:
#            last          email
# first
# shyam   bhosale  pqr@gmail.com
# ram       pawar  xyz@gmail.com
# pandav   jadhav   abcgmail.com
# harry     patil  uvw@gmail.com

# %%
df.reset_index(inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#     first     last          email
# 3   shyam  bhosale  pqr@gmail.com
# 2     ram    pawar  xyz@gmail.com
# 1  pandav   jadhav   abcgmail.com
# 0   harry    patil  uvw@gmail.com
