# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('survey_results_public.csv',low_memory=False)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df_schema=pd.read_csv('survey_results_schema.csv')

# %%
df_schema
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.info(show_counts=True,verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 172 columns):
#  #    Column                                    Non-Null Count  Dtype
# ---   ------                                    --------------  -----
#  0    ResponseId                                49191 non-null  int64
#  1    MainBranch                                49191 non-null  object
#  2    Age                                       49191 non-null  object
#  3    EdLevel                                   48149 non-null  object
#  4    Employment                                48339 non-null  object
#  5    EmploymentAddl                            44875 non-null  object
#  6    WorkExp                                   42893 non-null  float64
#  7    LearnCodeChoose                           46858 non-null  object
#  8    LearnCode                                 33556 non-null  object
#  9    LearnCodeAI                               45201 non-null  object
# ...

# %%
df['WorkExp'].head(50)
# Out:
# 0      8.0
# 1      2.0
# 2     10.0
# 3      4.0
# 4     21.0
# 5     15.0
# 6      9.0
# 7     22.0
# 8      9.0
# 9      7.0
# 10     7.0
# 11     3.0
# 12    10.0
# 13     6.0
# 14    15.0
# 15     5.0
# 16    20.0
# 17     1.0
# 18    20.0
# 19     3.0
# 20    40.0
# 21    35.0
# 22     7.0
# 23     2.0
# 24    40.0
# 25    37.0
# 26    26.0
# 27    24.0
# 28    13.0
# 29    19.0
# 30    20.0
# 31    17.0
# 32    26.0
# 33    24.0
# 34    22.0
# 35    10.0
# 36    10.0
# 37    15.0
# 38    25.0
# 39     7.0
# 40    33.0
# 41    25.0
# 42    25.0
# 43     8.0
# 44     4.0
# 45    20.0
# 46     NaN
# 47     5.0
# 48    15.0
# 49     6.0
# Name: WorkExp, dtype: float64

# %%
df['WorkExp'].median()
# Out:
# np.float64(10.0)

# %%
df['WorkExp'].mean()
# Out:
# np.float64(13.367402606485907)

# %%
df_schema
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
df_schema.loc[df_schema['qname'] == 'WorkExp', ['question','sub']]
# Out:
#                                              question  sub
# 54  How many years of professional work experience...  NaN

# %%
df_schema.loc[df_schema['qname']=='TechEndorse_1',['question']]
# Out:
#                                             question
# 0  What attracts you to a technology or causes yo...

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed                                                33750
# Independent contractor, freelancer, or self-employed     6708
# Student                                                  4428
# Not employed                                             2227
# Retired                                                   708
# I prefer not to say                                       518
# Name: count, dtype: int64

# %%
df['LanguageHaveWorkedWith'].value_counts().head(50)
# Out:
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript;TypeScript                                                     370
# Python                                                                             229
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                              193
# HTML/CSS;JavaScript;PHP;SQL                                                        180
# Python;SQL                                                                         169
# C#;HTML/CSS;JavaScript;SQL                                                         167
# C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript                                   160
# C#                                                                                 151
# Bash/Shell (all shells);Python;SQL                                                 143
# Bash/Shell (all shells);HTML/CSS;JavaScript;Python;SQL;TypeScript                  139
# ...

# %%
filt=df['Employment']=='Employed'

# %%
df.loc[filt,['Country']].value_counts(normalize=True)
# Out:
# Country
# United States of America                                0.216278
# Germany                                                 0.091977
# India                                                   0.067844
# United Kingdom of Great Britain and Northern Ireland    0.060932
# France                                                  0.039276
#                                                           ...
# Niger                                                   0.000040
# Senegal                                                 0.000040
# Sudan                                                   0.000040
# Timor-Leste                                             0.000040
# Turkmenistan                                            0.000040
# Name: proportion, Length: 163, dtype: float64

# %%
df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
#                                                         ...
# Lesotho                                                    1
# Djibouti                                                   1
# Cape Verde                                                 1
# Palau                                                      1
# Guinea                                                     1
# Name: count, Length: 177, dtype: int64

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp

# %%
usa_group=country_grp.get_group(('United States of America',))

# %%
usa_group
# Out:
#        ResponseId                                         MainBranch  \
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# 31             32                     I am a developer by profession
# 33             34                     I am a developer by profession
# ...           ...                                                ...
# 49125       49126  I work with developers or my work supports dev...
# 49127       49128                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49157       49158                     I am a developer by profession
# 49177       49178                              I am learning to code
#
#                    Age                                            EdLevel  \
# ...

# %%
usa_group['WorkExp'].mean()
# Out:
# np.float64(17.206566548881035)

# %%
filt_emp=usa_group['Employment']=='Employed'

# %%
usa_group.loc[filt_emp,'DevType'].value_counts()
# Out:
# DevType
# Developer, full-stack                            1724
# Developer, back-end                               712
# Architect, software or solutions                  367
# Developer, desktop or enterprise applications     268
# Engineering manager                               249
# Other (please specify):                           243
# Developer, front-end                              204
# Developer, embedded applications or devices       195
# DevOps engineer or professional                   170
# Data engineer                                     128
# Developer, mobile                                 122
# Data scientist                                    100
# Senior executive (C-suite, VP, etc.)               96
# Academic researcher                                94
# Cloud infrastructure engineer                      87
# AI/ML engineer                                     85
# System administrator                               73
# ...

# %%
usa_group.loc[filt_emp,'Industry'].value_counts()
# Out:
# Industry
# Software Development                          1991
# Other:                                         547
# Healthcare                                     381
# Government                                     373
# Fintech                                        266
# Manufacturing                                  265
# Internet, Telecomm or Information Services     249
# Higher Education                               235
# Banking/Financial Services                     207
# Retail and Consumer Services                   194
# Transportation, or Supply Chain                151
# Media & Advertising Services                   141
# Computer Systems Design and Services           136
# Energy                                         127
# Insurance                                      121
# Name: count, dtype: int64

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 172 columns):
#  #    Column                                    Dtype
# ---   ------                                    -----
#  0    ResponseId                                int64
#  1    MainBranch                                object
#  2    Age                                       object
#  3    EdLevel                                   object
#  4    Employment                                object
#  5    EmploymentAddl                            object
#  6    WorkExp                                   float64
#  7    LearnCodeChoose                           object
#  8    LearnCode                                 object
#  9    LearnCodeAI                               object
#  10   AILearnHow                                object
#  11   YearsCode                                 float64
#  12   DevType                                   object
# ...

# %%
df['WorkExp'].agg(['mean','median','std','var'])
# Out:
# mean       13.367403
# median     10.000000
# std        10.800117
# var       116.642523
# Name: WorkExp, dtype: float64

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df_india_python=df[(df['Country'] == 'India') &  (df['LanguageHaveWorkedWith'].str.contains('Python', na=False))]

# %%
df_india_python
# Out:
#        ResponseId                                         MainBranch  \
# 15             16                     I am a developer by profession
# 46             47                     I am a developer by profession
# 90             91                     I am a developer by profession
# 181           182  I am not primarily a developer, but I write co...
# 253           254  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 48984       48985                     I am a developer by profession
# 48995       48996                     I am a developer by profession
# 49089       49090                              I am learning to code
# 49132       49133                        I code primarily as a hobby
# 49141       49142                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
df_india_python['Employment'].value_counts(normalize=True)
# Out:
# Employment
# Employed                                                0.617040
# Student                                                 0.221170
# Independent contractor, freelancer, or self-employed    0.100688
# Not employed                                            0.055077
# I prefer not to say                                     0.004303
# Retired                                                 0.001721
# Name: proportion, dtype: float64
