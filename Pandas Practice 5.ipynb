# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.0'

# %%
people={
    'first':['harry','ram','shyam','pandav'],
    'last':['patil','pawar','bhosale','jadhav'],
    'email':['uvw@gmail.com','xyz@gmail.com','pqr@gmail.com','abcgmail.com'],
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last          email
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#     FIRST     LAST          EMAIL
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df.columns=['first_name','last_name','email']

# %%
df
# Out:
#   first_name last_name          email
# 0      harry     patil  uvw@gmail.com
# 1        ram     pawar  xyz@gmail.com
# 2      shyam   bhosale  pqr@gmail.com
# 3     pandav    jadhav   abcgmail.com

# %%
df.columns=df.columns.str.replace('_'," ")
df
# Out:
#   first name last name          email
# 0      harry     patil  uvw@gmail.com
# 1        ram     pawar  xyz@gmail.com
# 2      shyam   bhosale  pqr@gmail.com
# 3     pandav    jadhav   abcgmail.com

# %%
df.columns=['first','last','email']

# %%
df
# Out:
#     first     last          email
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df['full']=df['first']+' '+df['last']

# %%
df
# Out:
#     first     last          email           full
# 0   harry    patil  uvw@gmail.com    harry patil
# 1     ram    pawar  xyz@gmail.com      ram pawar
# 2   shyam  bhosale  pqr@gmail.com  shyam bhosale
# 3  pandav   jadhav   abcgmail.com  pandav jadhav

# %%
df.rename(columns={'first':'first_name','last':'last_name','full':'full_name'},inplace=True)

# %%
df
# Out:
#   first_name last_name          email      full_name
# 0      harry     patil  uvw@gmail.com    harry patil
# 1        ram     pawar  xyz@gmail.com      ram pawar
# 2      shyam   bhosale  pqr@gmail.com  shyam bhosale
# 3     pandav    jadhav   abcgmail.com  pandav jadhav

# %%
df.loc[3]=['Pandav','Jadhav','pandavjadhav@gmail.com','Pandav Jadhav']

# %%
df
# Out:
#   first_name last_name                   email      full_name
# 0      harry     patil           uvw@gmail.com    harry patil
# 1        ram     pawar           xyz@gmail.com      ram pawar
# 2      shyam   bhosale           pqr@gmail.com  shyam bhosale
# 3     Pandav    Jadhav  pandavjadhav@gmail.com  Pandav Jadhav

# %%
df.loc[0,['first_name','last_name']]=['Rutwik','Patil']

# %%
df
# Out:
#   first_name last_name                   email      full_name
# 0     Rutwik     Patil           uvw@gmail.com    harry patil
# 1        ram     pawar           xyz@gmail.com      ram pawar
# 2      shyam   bhosale           pqr@gmail.com  shyam bhosale
# 3     Pandav    Jadhav  pandavjadhav@gmail.com  Pandav Jadhav

# %%
df.loc[1,'first_name']='Ram'

# %%
df
# Out:
#   first_name last_name                   email      full_name
# 0     Rutwik     Patil           uvw@gmail.com    harry patil
# 1        Ram     pawar           xyz@gmail.com      ram pawar
# 2      shyam   bhosale           pqr@gmail.com  shyam bhosale
# 3     Pandav    Jadhav  pandavjadhav@gmail.com  Pandav Jadhav

# %%
df['first_name']=df['first_name'].str.title()

# %%
df
# Out:
#   first_name last_name                   email      full_name
# 0     Rutwik     Patil           uvw@gmail.com    harry patil
# 1        Ram     pawar           xyz@gmail.com      ram pawar
# 2      Shyam   bhosale           pqr@gmail.com  shyam bhosale
# 3     Pandav    Jadhav  pandavjadhav@gmail.com  Pandav Jadhav

# %%
df['last_name']=df['last_name'].str.title()

# %%
df
# Out:
#   first_name last_name                   email      full_name
# 0     Rutwik     Patil           uvw@gmail.com    harry patil
# 1        Ram     Pawar           xyz@gmail.com      ram pawar
# 2      Shyam   Bhosale           pqr@gmail.com  shyam bhosale
# 3     Pandav    Jadhav  pandavjadhav@gmail.com  Pandav Jadhav
