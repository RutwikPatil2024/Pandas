# %%
import pandas as pd

# %%
people={
    'first':['harry','ram','shyam','pandav'],
    'last':['patil','pawar','bhosale','jadhav'],
    'email':['uvw@gmail.com','xyz@gmail.com','pqr@gmail.com','abcgmail.com'],
}

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#     first     last          email
# 0   harry    patil  uvw@gmail.com
# 1     ram    pawar  xyz@gmail.com
# 2   shyam  bhosale  pqr@gmail.com
# 3  pandav   jadhav   abcgmail.com

# %%
df['first']
# Out:
# 0     harry
# 1       ram
# 2     shyam
# 3    pandav
# Name: first, dtype: object

# %%
type(df['first'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.email
# Out:
# 0    uvw@gmail.com
# 1    xyz@gmail.com
# 2    pqr@gmail.com
# 3     abcgmail.com
# Name: email, dtype: object

# %%
df[['first','email']]
# Out:
#     first          email
# 0   harry  uvw@gmail.com
# 1     ram  xyz@gmail.com
# 2   shyam  pqr@gmail.com
# 3  pandav   abcgmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first            harry
# last             patil
# email    uvw@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,2]]
# Out:
#    first     last          email
# 0  harry    patil  uvw@gmail.com
# 2  shyam  bhosale  pqr@gmail.com

# %%
# df.iloc[[0,2],'last']  not allowed here but use only index only

# %%
df.iloc[[0,2],1]
# Out:
# 0      patil
# 2    bhosale
# Name: last, dtype: object

# %%
df.iloc[[0,2],[1,2]]
# Out:
#       last          email
# 0    patil  uvw@gmail.com
# 2  bhosale  pqr@gmail.com

# %%
df.loc[[0,1]]
# Out:
#    first   last          email
# 0  harry  patil  uvw@gmail.com
# 1    ram  pawar  xyz@gmail.com

# %%
df.loc[[0,1],['first','email']]
# Out:
#    first          email
# 0  harry  uvw@gmail.com
# 1    ram  xyz@gmail.com

# %%
df.loc[0,'first']
# Out:
# 'harry'

# %%
df['hobby']=['yes','no','yes','yes']

# %%
df
# Out:
#     first     last          email hobby
# 0   harry    patil  uvw@gmail.com   yes
# 1     ram    pawar  xyz@gmail.com    no
# 2   shyam  bhosale  pqr@gmail.com   yes
# 3  pandav   jadhav   abcgmail.com   yes

# %%
df['hobby'].value_counts()
# Out:
# hobby
# yes    3
# no     1
# Name: count, dtype: int64

# %%
df.loc[0:2,'hobby']
# Out:
# 0    yes
# 1     no
# 2    yes
# Name: hobby, dtype: object

# %%
df.loc[0:2,'last':'hobby']
# Out:
#       last          email hobby
# 0    patil  uvw@gmail.com   yes
# 1    pawar  xyz@gmail.com    no
# 2  bhosale  pqr@gmail.com   yes
